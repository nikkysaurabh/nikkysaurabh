# %% [markdown]
# <a href="https://www.kaggle.com/saurabh008978/uber-driver?scriptVersionId=88539919" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# The project is based on Uber driver journeys. We are using Exploratory Data Analysis to analyse various aspects of the trips.

# %% [markdown]
# Load the necessary libraries. Import and load the dataset with a name uber_drives .

# %%
import numpy as np
import pandas as pd

# %%
# Get the Data
uber_driver = pd.read_csv("../input/uberdrives/uberdrives (2).csv")

# %%
uber_driver.head()
# Out:
#         START_DATE*         END_DATE* CATEGORY*       START*            STOP*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
uber_driver.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*        PURPOSE*
# 1150           Karachi     0.7         Meeting
# 1151  Unknown Location     3.9  Temporary Site
# 1152  Unknown Location    16.2         Meeting
# 1153           Gampaha     6.4  Temporary Site
# 1154         Ilukwatta    48.2  Temporary Site

# %%
print(uber_driver.shape)
print("The number of rows in the dataset are",uber_driver.shape[0])
print("The number of columns in the dataset are",uber_driver.shape[1])
# Out:
# (1155, 7)
# The number of rows in the dataset are 1155
# The number of columns in the dataset are 7

# %%
print(uber_driver.size)
# Out:
# 8085

# %%
#information about all the variables of the data set
uber_driver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
#check for missing values
uber_driver.isna().values.sum()
# Out:
# 502

# %%
#summary of dataset
uber_driver.describe()
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %%
#Creating new data set df by dropping missing values
df=uber_driver.dropna()

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
#unique start location
df["START*"].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Lake Wellingborough',
#        'Fayetteville Street', 'Raleigh', 'Whitebridge', 'Hazelwood',
#        'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill', 'Northwoods',
#        'Edgehill Farms', 'Eastgate', 'East Elmhurst', 'Long Island City',
#        'Katunayaka', 'Colombo', 'Nugegoda', 'Unknown Location',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Preston',
#        'Heritage Pines', 'Tanglewood', 'Waverly Place', 'Wayne Ridge',
#        'Westpark Place', 'East Austin', 'The Drag', 'South Congress',
#        'Georgian Acres', 'North Austin', 'West University', 'Austin',
# ...

# %%
df["START*"].nunique()
# Out:
# 131

# %%
#all Uber trips that has the starting point as San Francisco
df.loc[df["START*"]=="San Francisco"]
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %%
#most popular starting point for the Uber drivers
df["START*"].value_counts().head(10)
# Out:
# Cary                161
# Unknown Location     55
# Morrisville          54
# Whitebridge          36
# Durham               30
# Karachi              26
# Raleigh              21
# Lahore               19
# Islamabad            15
# Apex                 11
# Name: START*, dtype: int64

# %%
#most popular dropping point for the uber drivers
df["STOP*"].value_counts().head(10)
# Out:
# Cary                155
# Morrisville          60
# Unknown Location     56
# Whitebridge          37
# Durham               30
# Karachi              26
# Raleigh              21
# Lahore               19
# Islamabad            14
# Apex                 11
# Name: STOP*, dtype: int64

# %%
#purpose of the trip
df['PURPOSE*'].unique()
# Out:
# array(['Meal/Entertain', 'Errand/Supplies', 'Meeting', 'Customer Visit',
#        'Temporary Site', 'Between Offices', 'Charity ($)', 'Commute',
#        'Moving', 'Airport/Travel'], dtype=object)

# %%
#most common purpose of the trip
df['PURPOSE*'].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE*, dtype: int64
